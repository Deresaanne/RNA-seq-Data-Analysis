# %%
fastqc --o //coursedata/users/leey17 --extract //coursedata/project/RNA-seq-data/RNA-seq-raw/dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Out:
# Started analysis of dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 5% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 10% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 15% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 20% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 25% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 30% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 35% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 40% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 45% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 50% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 55% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 60% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# Approx 65% complete for dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz
# ...

# %%
fastqc --o //coursedata/users/leey17 --extract //coursedata/project/RNA-seq-data/RNA-seq-raw/dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Out:
# Started analysis of dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 5% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 10% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 15% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 20% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 25% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 30% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 35% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 40% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 45% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 50% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 55% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 60% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Approx 65% complete for dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# ...

# %%
tophat2 --library-type fr-firststrand --no-coverage-search -o //coursedata/users/leey17 --transcriptome-index //coursedata/project/RNA-seq-data/transcriptome_data_index/transcriptome_grch38_v22 //coursedata/project/bowtie2-index/GRCh38 //coursedata/project/RNA-seq-data/RNA-seq-raw/dexamethasone_1hour_Rep3_PairedEnd1.fastq.gz //coursedata/project/RNA-seq-data/RNA-seq-raw/dexamethasone_1hour_Rep3_PairedEnd2.fastq.gz
# Out:
# [2021-11-29 01:00:49] Beginning TopHat run (v2.1.1)
# -----------------------------------------------
# [2021-11-29 01:00:49] Checking for Bowtie
# 		  Bowtie version:	 2.4.2.0
# [2021-11-29 01:00:49] Checking for Bowtie index files (transcriptome)..
# [2021-11-29 01:00:49] Checking for Bowtie index files (genome)..
# [2021-11-29 01:00:49] Checking for reference FASTA file
# [2021-11-29 01:00:49] Generating SAM header for //coursedata/project/bowtie2-index/GRCh38
# [2021-11-29 01:00:54] Reading known junctions from GTF file
# [2021-11-29 01:01:17] Preparing reads
# [2021-11-29 02:49:56] Mapping right_kept_reads to transcriptome transcriptome_grch38_v22 with Bowtie2
# [2021-11-29 04:27:25] Resuming TopHat pipeline with unmapped reads
# [2021-11-29 04:27:25] Mapping left_kept_reads.m2g_um to genome GRCh38 with Bowtie2
# [2021-11-29 04:49:44] Mapping left_kept_reads.m2g_um_seg1 to genome GRCh38 with Bowtie2 (1/2)
# ...

# %%
samtools sort -o accepted_hits.sorted.bam -n -T out.prefix.bam accepted_hits.bam
# Out:
# [bam_sort_core] merging from 21 files and 1 in-memory blocks...

# %%
htseq-count --format=bam --order=name --stranded=reverse --type=exon --idattr=gene_id --mode=intersection-strict //coursedata/users/leey17/accepted_hits.sorted.bam //coursedata/project/RNA-seq-data/gencode.v22.annotation.gtf > result_file1.txt
# Out:
# 100000 GFF lines processed.
# 200000 GFF lines processed.
# 300000 GFF lines processed.
# 400000 GFF lines processed.
# 500000 GFF lines processed.
# 600000 GFF lines processed.
# 700000 GFF lines processed.
# 800000 GFF lines processed.
# 900000 GFF lines processed.
# 1000000 GFF lines processed.
# 1100000 GFF lines processed.
# 2563671 GFF lines processed.
# [E::idx_find_and_load] Could not retrieve index file for '//coursedata/users/leey17/accepted_hits.sorted.bam'
# 100000 SAM alignment record pairs processed.
# 200000 SAM alignment record pairs processed.
# 300000 SAM alignment record pairs processed.
# 400000 SAM alignment record pairs processed.
# 500000 SAM alignment record pairs processed.
# 600000 SAM alignment record pairs processed.
# 700000 SAM alignment record pairs processed.
# 800000 SAM alignment record pairs processed.
# 900000 SAM alignment record pairs processed.
# 1000000 SAM alignment record pairs processed.
# 1100000 SAM alignment record pairs processed.
# ...

# %%
htseq-count --format=bam --order=name --stranded=reverse --type=exon --idattr=gene_id --mode=intersection-nonempty //coursedata/users/leey17/accepted_hits.sorted.bam //coursedata/project/RNA-seq-data/gencode.v22.annotation.gtf > result_file2.txt
# Out:
# 100000 GFF lines processed.
# 200000 GFF lines processed.
# 300000 GFF lines processed.
# 400000 GFF lines processed.
# 500000 GFF lines processed.
# 600000 GFF lines processed.
# 700000 GFF lines processed.
# 800000 GFF lines processed.
# 900000 GFF lines processed.
# 1000000 GFF lines processed.
# 1100000 GFF lines processed.
# 1200000 GFF lines processed.
# 1300000 GFF lines processed.
# 1400000 GFF lines processed.
# 1500000 GFF lines processed.
# 1600000 GFF lines processed.
# 1700000 GFF lines processed.
# 1800000 GFF lines processed.
# 2100000 GFF lines processed.
# 2200000 GFF lines processed.
# 2300000 GFF lines processed.
# 2400000 GFF lines processed.
# 2500000 GFF lines processed.
# 2563671 GFF lines processed.
# [E::idx_find_and_load] Could not retrieve index file for '//coursedata/users/leey17/accepted_hits.sorted.bam'
# 100000 SAM alignment record pairs processed.
# 200000 SAM alignment record pairs processed.
# 300000 SAM alignment record pairs processed.
# ...

# %%
htseq-count --format=bam --order=name --stranded=reverse --type=exon --idattr=gene_id --mode=union //coursedata/users/leey17/accepted_hits.sorted.bam //coursedata/project/RNA-seq-data/gencode.v22.annotation.gtf > result_file3.txt
# Out:
# 100000 GFF lines processed.
# 200000 GFF lines processed.
# 300000 GFF lines processed.
# 400000 GFF lines processed.
# 500000 GFF lines processed.
# 600000 GFF lines processed.
# 700000 GFF lines processed.
# 800000 GFF lines processed.
# 900000 GFF lines processed.
# 1000000 GFF lines processed.
# 1100000 GFF lines processed.
# 1200000 GFF lines processed.
# 1300000 GFF lines processed.
# 1400000 GFF lines processed.
# 1500000 GFF lines processed.
# 1600000 GFF lines processed.
# 1700000 GFF lines processed.
# 1800000 GFF lines processed.
# 1900000 GFF lines processed.
# 2000000 GFF lines processed.
# 2100000 GFF lines processed.
# 2200000 GFF lines processed.
# 2300000 GFF lines processed.
# 2400000 GFF lines processed.
# 2500000 GFF lines processed.
# 2563671 GFF lines processed.
# [E::idx_find_and_load] Could not retrieve index file for '//coursedata/users/leey17/accepted_hits.sorted.bam'
# 100000 SAM alignment record pairs processed.
# ...
